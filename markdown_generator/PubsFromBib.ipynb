# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
# !pip install pybtex
# Out:
# Collecting pybtex
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: PyYAML>=3.01 in /home/codespace/.local/lib/python3.12/site-packages (from pybtex) (6.0.2)
# Collecting latexcodec>=1.0.4 (from pybtex)
#   Downloading latexcodec-3.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.12/site-packages (from pybtex) (1.17.0)
# Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 26.7 MB/s eta 0:00:00
# Downloading latexcodec-3.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: latexcodec, pybtex
# Successfully installed latexcodec-3.0.0 pybtex-0.24.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "radin.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "radin.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/tois/RadFBKSS24: " A Variational Neural Architect ... "
# SUCESSFULLY PARSED DBLP:conf/ecir/RadCCG24: " Interactive Topic Tagging in Community Question Answering Pl ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/ir/RadNABKSSZ23: " Learning heterogeneous subgrap ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/isci/NguyenRZB23: " DyHNet: Learning dynamic heter ... "
# SUCESSFULLY PARSED DBLP:conf/cikm/ArabzadehRKB23: " Noisy Perturbations for Estimating Query Difficulty in Dense ... "
# SUCESSFULLY PARSED DBLP:conf/intellisys/RadZMSH23: " Recommendation System over Multi-layer Complex Networks: {A} ... "
# SUCESSFULLY PARSED DBLP:conf/sigir/ArabzadehBRB23: " Quantifying Ranker Coverage of Different Query Subspaces  "
# SUCESSFULLY PARSED DBLP:conf/sigir/Rad23: " Neural Architectures for Searching Subgraph Structures  "
# SUCESSFULLY PARSED DBLP:conf/cikm/NguyenRB22: " PyDHNet: {A} Python Library for Dynamic Heterogeneous Networ ... "
# SUCESSFULLY PARSED DBLP:conf/edbt/RadSKZB22: " A Neural Approach to Forming Coherent Teams in Collaboration ... "
# SUCESSFULLY PARSED DBLP:conf/websci/RadBKSS22: " Subgraph Representation Learning for Team Mining  "
# SUCESSFULLY PARSED DBLP:conf/cikm/RadMFKSB21: " PyTFL: {A} Python-based Neural Team Formation Toolkit  "
# SUCESSFULLY PARSED DBLP:conf/sigir/RadBKSS21: " Retrieving Skill-Based Teams from Collaboration Networks  "
# SUCESSFULLY PARSED DBLP:conf/cikm/RadFKSB20: " Learning to Form Skill-based Teams of Experts  "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-1902-03609: " Hybrid Forest: {A} Concept Dri ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-1812-09380: " A Fuzzy Community-Based Recomm ... "
# SUCESSFULLY PARSED DBLP:journals/tois/RadFBKSS24: " A Variational Neural Architecture for Skill-based Team Forma ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/ecir/RadCCG24: " Interactive Topic Tagging in C ... "
# SUCESSFULLY PARSED DBLP:journals/ir/RadNABKSSZ23: " Learning heterogeneous subgraph representations for team dis ... "
# SUCESSFULLY PARSED DBLP:journals/isci/NguyenRZB23: " DyHNet: Learning dynamic heterogeneous network representatio ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/cikm/ArabzadehRKB23: " Noisy Perturbations for Estima ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/intellisys/RadZMSH23: " Recommendation System over Mul ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/sigir/ArabzadehBRB23: " Quantifying Ranker Coverage of ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/sigir/Rad23: " Neural Architectures for Searc ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/cikm/NguyenRB22: " PyDHNet: {A} Python Library fo ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/edbt/RadSKZB22: " A Neural Approach to Forming C ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/websci/RadBKSS22: " Subgraph Representation Learni ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/cikm/RadMFKSB21: " PyTFL: {A} Python-based Neural ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/sigir/RadBKSS21: " Retrieving Skill-Based Teams f ... "
# WARNING Missing Expected Field 'journal' from entry DBLP:conf/cikm/RadFKSB20: " Learning to Form Skill-based T ... "
# SUCESSFULLY PARSED DBLP:journals/corr/abs-1902-03609: " Hybrid Forest: {A} Concept Drift Aware Data Stream Mining Al ... "
# SUCESSFULLY PARSED DBLP:journals/corr/abs-1812-09380: " A Fuzzy Community-Based Recommender System Using PageRank  "
